# %%
from PIL import Image
import os, glob, numpy as np


caltech_dir = "C:/Datasets/train"
categories = ["B7","B9","B10","B13","B14","B15","B16", "B17" ,"C"]
nb_classes = len(categories)

image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X1 = []
X2 = []
X3 = []
X4 = []
X5 = []
X6 = []
X7 = []
X8 = []
X9 = []
X10 = []
X11 = []
X12 = []
y1 = []
y2 = []
y3 = []
y4 = []
y5 = []
y6 = []
y7 = []
y8 = []
y9 = []
y10 = []
y11 = []
y12 = []

j=0
for idx, B7 in enumerate(categories):
    
    #one-hot 돌리기.
    label = [0 for i in range(nb_classes)]
    label[idx] = 1

    image_dir = caltech_dir + "/" + B7
    files = glob.glob(image_dir+"/*.png")
    print(B7, " 파일 길이 : ", len(files))
    
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)
        
        if(j%12==0):
            X1.append(data)
            y1.append(label)
        if(j%12==1):
            X2.append(data)
            y2.append(label)
        if(j%12==2):
            X3.append(data)
            y3.append(label)
        if(j%12==3):
            X4.append(data)
            y4.append(label)
        if(j%12==4):
            X5.append(data)
            y5.append(label)
        if(j%12==5):
            X6.append(data)
            y6.append(label)
        if(j%12==6):
            X7.append(data)
            y7.append(label)
        if(j%12==7):
            X8.append(data)
            y8.append(label)
        if(j%12==8):
            X9.append(data)
            y9.append(label)
        if(j%12==9):
            X10.append(data)
            y10.append(label)
        if(j%12==10):
            X11.append(data)
            y11.append(label)
        if(j%12==11):
            X12.append(data)
            y12.append(label)

        j=j+1

        if i % 100 == 0:
            print(B7, " : ", f)
            
X_train_s1 = np.array(X1)
X_train_s2 = np.array(X2)
X_train_s3 = np.array(X3)
X_train_s4 = np.array(X4)
X_train_s5 = np.array(X5)
X_train_s6 = np.array(X6)
X_train_s7 = np.array(X7)
X_train_s8 = np.array(X8)
X_train_s9 = np.array(X9)
X_train_s10 = np.array(X10)
X_train_s11 = np.array(X11)
X_train_s12 = np.array(X12)
y_train = np.array(y1)

caltech_dir = "C:/Datasets/val"
categories = ["val_B7","val_B9","val_B10","val_B13","val_B14","val_B15","val_B16", "val_B17" ,"val_C"]
nb_classes = len(categories)

image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X1 = []
X2 = []
X3 = []
X4 = []
X5 = []
X6 = []
X7 = []
X8 = []
X9 = []
X10 = []
X11 = []
X12 = []
y1 = []
y2 = []
y3 = []
y4 = []
y5 = []
y6 = []
y7 = []
y8 = []
y9 = []
y10 = []
y11 = []
y12 = []

j=0
for idx, val_B7 in enumerate(categories):
    
    #one-hot 돌리기.
    label = [0 for i in range(nb_classes)]
    label[idx] = 1

    image_dir = caltech_dir + "/" + val_B7
    files = glob.glob(image_dir+"/*.png")
    print(B7, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        if(j%12==0):
            X1.append(data)
            y1.append(label)
        if(j%12==1):
            X2.append(data)
            y2.append(label)
        if(j%12==2):
            X3.append(data)
            y3.append(label)
        if(j%12==3):
            X4.append(data)
            y4.append(label)
        if(j%12==4):
            X5.append(data)
            y5.append(label)
        if(j%12==5):
            X6.append(data)
            y6.append(label)
        if(j%12==6):
            X7.append(data)
            y7.append(label)
        if(j%12==7):
            X8.append(data)
            y8.append(label)
        if(j%12==8):
            X9.append(data)
            y9.append(label)
        if(j%12==9):
            X10.append(data)
            y10.append(label)
        if(j%12==10):
            X11.append(data)
            y11.append(label)
        if(j%12==11):
            X12.append(data)
            y12.append(label)

        j=j+1


        if i % 100 == 0:
            print(val_B7, " : ", f)
    
X_test_s1 = np.array(X1)
X_test_s2 = np.array(X2)
X_test_s3 = np.array(X3)
X_test_s4 = np.array(X4)
X_test_s5 = np.array(X5)
X_test_s6 = np.array(X6)
X_test_s7 = np.array(X7)
X_test_s8 = np.array(X8)
X_test_s9 = np.array(X9)
X_test_s10 = np.array(X10)
X_test_s11 = np.array(X11)
X_test_s12 = np.array(X12)
y_test = np.array(y1)

xy = (X_train_s1, X_train_s2, X_train_s3, X_train_s4, X_train_s5, X_train_s6, X_train_s7, X_train_s8, X_train_s9, X_train_s10, X_train_s11, X_train_s12, X_test_s1, X_test_s2, X_test_s3, X_test_s4, X_test_s5, X_test_s6, X_test_s7, X_test_s8, X_test_s9, X_test_s10, X_test_s11, X_test_s12, y_train, y_test)
np.save("C:/Datasets/train/multi_image_data.npy", xy)

print("ok", len(y1))
# Out:
# B7  파일 길이 :  1932
# B7  :  C:/Datasets/train/B7\S10E1_a7-1_s1.png
# B7  :  C:/Datasets/train/B7\S12E1_a7-1_s2.png
# B7  :  C:/Datasets/train/B7\S14E1_a7-1_s6.png
# B7  :  C:/Datasets/train/B7\S16E1_a7-2_s1.png
# B7  :  C:/Datasets/train/B7\S18E1_a7-2_s2.png
# B7  :  C:/Datasets/train/B7\S1E1_a7-2_s6.png
# B7  :  C:/Datasets/train/B7\S21E1_a7-3_s1.png
# B7  :  C:/Datasets/train/B7\S23E1_a7-1_s2.png
# B7  :  C:/Datasets/train/B7\S24E1_a7-4_s6.png
# B7  :  C:/Datasets/train/B7\S26E1_a7-6_s1.png
# B7  :  C:/Datasets/train/B7\S28E1_a7-6_s2.png
# B7  :  C:/Datasets/train/B7\S2E1_a7-4_s6.png
# B7  :  C:/Datasets/train/B7\S32E1_a7-2_s1.png
# B7  :  C:/Datasets/train/B7\S34E1_a7-2_s2.png
# B7  :  C:/Datasets/train/B7\S36E1_a7-3_s6.png
# B7  :  C:/Datasets/train/B7\S38E1_a7-6_s1.png
# B7  :  C:/Datasets/train/B7\S3E1_a7-4_s2.png
# B7  :  C:/Datasets/train/B7\S5E1_a7-1_s6.png
# B7  :  C:/Datasets/train/B7\S7E1_a7-2_s1.png
# B7  :  C:/Datasets/train/B7\S9E1_a7-2_s2.png
# B9  파일 길이 :  3864
# ...

# %%
import os, glob, numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

X_train_s1, X_train_s2, X_train_s3, X_train_s4, X_train_s5, X_train_s6, X_train_s7, X_train_s8, X_train_s9, X_train_s10, X_train_s11, X_train_s12, X_test_s1, X_test_s2, X_test_s3, X_test_s4, X_test_s5, X_test_s6, X_test_s7, X_test_s8, X_test_s9, X_test_s10, X_test_s11, X_test_s12, y_train, y_test = np.load('C:/Datasets/train/multi_image_data.npy')
print(X_train_s1.shape)
print(X_train_s1.shape[0])
# Out:
# (2584, 64, 64, 3)
# 2584

# %%
categories = ["B7","B9","B10","B13","B14","B15","B16", "B17" ,"C"]
nb_classes = len(categories)

#일반화
X_train_s1 = X_train_s1.astype(float) / 255
X_train_s2 = X_train_s2.astype(float) / 255
X_train_s3 = X_train_s3.astype(float) / 255
X_train_s4 = X_train_s4.astype(float) / 255
X_train_s5 = X_train_s5.astype(float) / 255
X_train_s6 = X_train_s6.astype(float) / 255
X_train_s7 = X_train_s7.astype(float) / 255
X_train_s8 = X_train_s8.astype(float) / 255
X_train_s9 = X_train_s9.astype(float) / 255
X_train_s10 = X_train_s10.astype(float) / 255
X_train_s11 = X_train_s11.astype(float) / 255
X_train_s12 = X_train_s12.astype(float) / 255
X_test_s1 = X_test_s1.astype(float) / 255
X_test_s2 = X_test_s2.astype(float) / 255
X_test_s3 = X_test_s3.astype(float) / 255
X_test_s4 = X_test_s4.astype(float) / 255
X_test_s5 = X_test_s5.astype(float) / 255
X_test_s6 = X_test_s6.astype(float) / 255
X_test_s7 = X_test_s7.astype(float) / 255
X_test_s8 = X_test_s8.astype(float) / 255
X_test_s9 = X_test_s9.astype(float) / 255
X_test_s10 = X_test_s10.astype(float) / 255
X_test_s11 = X_test_s11.astype(float) / 255
X_test_s12 = X_test_s12.astype(float) / 255

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, Input, concatenate

sensor=[]
x=[]
for i in range(12):
    sensor.insert(i,Input(shape=(64,64,3)))

for i in range(12):
    x.insert(i,Conv2D(filters=32, kernel_size=3, activation=tf.nn.relu, padding='SAME')(sensor[i]))
    x[i]=MaxPooling2D(padding ='SAME')(x[i])
    x[i]=Conv2D(filters=64, kernel_size=3, activation=tf.nn.relu, padding='SAME')(x[i])
    x[i]=MaxPooling2D(padding ='SAME')(x[i])
    x[i]=Conv2D(filters=128, kernel_size=3, activation=tf.nn.relu, padding='SAME')(x[i])
    x[i]=MaxPooling2D(padding ='SAME')(x[i])
    x[i]=Flatten()(x[i])
    x[i]=Dense(256, activation = tf.nn.relu)(x[i])
    x[i]=Dropout(0.5)(x[i])
    x[i]=Dense(128, activation = tf.nn.relu)(x[i])
    x[i]=Dropout(0.5)(x[i])
    x[i]=Dense(64, activation = tf.nn.relu)(x[i])
    x[i]=Dropout(0.5)(x[i])
    x[i]=Dense(1)(x[i])
    x[i]= Model(inputs=sensor[i], outputs=x[i])

result = concatenate([x[0].output,x[1].output, x[2].output, x[3].output, x[4].output, x[5].output, x[6].output, x[7].output, x[8].output, x[9].output, x[10].output, x[11].output])

output = Dense(12, activation="relu")(result)
output = Dense(9, activation="softmax")(output)


model = Model(inputs=[x[0].input, x[1].input, x[2].input, x[3].input, x[4].input, x[5].input, x[6].input, x[7].input, x[8].input, x[9].input, x[10].input, x[11].input],outputs=output)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_dir = './model'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)
    
model_path = model_dir + '/multi_img_classification.model3'
checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=6)

# %%
model.summary()
from keras.utils import plot_model
plot_model(model, "multi_input_and_output_model3.png", show_shapes=True)
# Out:
# Model: "model_26"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_13 (InputLayer)           (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# ...

# %%
history = model.fit([X_train_s1,X_train_s2,X_train_s3,X_train_s4,X_train_s5,X_train_s6,X_train_s7,X_train_s8,X_train_s9,X_train_s10,X_train_s11,X_train_s12], y_train, batch_size=32, epochs=50, validation_data=([X_test_s1,X_test_s2,X_test_s3,X_test_s4,X_test_s5,X_test_s6,X_test_s7,X_test_s8,X_test_s9,X_test_s10,X_test_s11,X_test_s12] ,y_test), callbacks=[checkpoint, early_stopping])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 2584 samples, validate on 872 samples
# Epoch 1/50
# 2584/2584 [==============================] - 143s 55ms/step - loss: 2.0158 - accuracy: 0.3526 - val_loss: 1.8640 - val_accuracy: 0.3727
#
# Epoch 00001: val_loss improved from inf to 1.86404, saving model to ./model/multi_img_classification.model3
# Epoch 2/50
# 2584/2584 [==============================] - 133s 51ms/step - loss: 1.7158 - accuracy: 0.4071 - val_loss: 1.4961 - val_accuracy: 0.4541
#
# Epoch 00002: val_loss improved from 1.86404 to 1.49607, saving model to ./model/multi_img_classification.model3
# Epoch 3/50
# 2584/2584 [==============================] - 131s 51ms/step - loss: 1.5262 - accuracy: 0.4559 - val_loss: 1.3958 - val_accuracy: 0.5229
#
# ...

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label='val_set_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='train_set_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.show()

# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

caltech_dir = "C:/Datasets/test"
categories = ["B7","B9","B10","B13","B14","B15","B16", "B17" ,"C"]
nb_classes = len(categories)
image_w = 64
image_h = 64
len_img=0

pixels = image_h * image_w * 3

X = []
y = []
filenames = []

for idx, B7 in enumerate(categories):
    label = [0 for i in range(nb_classes)]
    label[idx] = 1
    image_dir = caltech_dir + "/" + B7
    files = glob.glob(image_dir+"/*.png")
    len_img=len_img+len(files)
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)
        filenames.append(f)
        X.append(data)
        y.append(label)

len_img_per_12=int(len_img/12)
filenames = np.asarray(filenames)
filenames = filenames.reshape (len_img_per_12,12) # 24x12
X = np.asarray(X)
X = np.reshape(X, (len_img_per_12,12,64,64,3)) # 24X12 , 3, 64, 64
y = np.asarray(y)
y = np.reshape(y,(len_img_per_12,12,nb_classes))


X_all = np.array(X)
y_all = np.array(y)
X_B7 = np.array(X[0:24])
y_B7 = np.array(y[0:24])
X_B9 = np.array(X[24:72])
y_B9 = np.array(y[24:72])
X_B10 = np.array(X[72:120])
y_B10 = np.array(y[72:120])
X_B13 = np.array(X[120:144])
y_B13 = np.array(y[120:144])
X_B14 = np.array(X[144:168])
y_B14 = np.array(y[144:168])
X_B15 = np.array(X[168:192])
y_B15 = np.array(y[168:192])
X_B16 = np.array(X[192:216])
y_B16 = np.array(y[192:216])
X_B17 = np.array(X[216:240])
y_B17 = np.array(y[216:240])
X_C = np.array(X[240:384])
y_C = np.array(y[240:384])

model = load_model('./model/multi_img_classification.model3')
X_all = np.swapaxes(X_all,0,1)
print(np.shape(X_all[0]))
y_all = np.swapaxes(y_all,0,1)
print(np.shape(y_all[0]))
X_B7 = np.swapaxes(X_B7,0,1)
y_B7 = np.swapaxes(y_B7,0,1)
X_B9 = np.swapaxes(X_B9,0,1)
y_B9 = np.swapaxes(y_B9,0,1)
X_B10 = np.swapaxes(X_B10,0,1)
y_B10 = np.swapaxes(y_B10,0,1)
X_B13 = np.swapaxes(X_B13,0,1)
y_B13 = np.swapaxes(y_B13,0,1)
X_B14 = np.swapaxes(X_B14,0,1)
y_B14 = np.swapaxes(y_B14,0,1)
X_B15 = np.swapaxes(X_B15,0,1)
y_B15 = np.swapaxes(y_B15,0,1)
X_B16 = np.swapaxes(X_B16,0,1)
y_B16 = np.swapaxes(y_B16,0,1)
X_B17 = np.swapaxes(X_B17,0,1)
y_B17 = np.swapaxes(y_B17,0,1)
X_C = np.swapaxes(X_C,0,1)
y_C = np.swapaxes(y_C,0,1)

prediction = model.predict([X_all[0],X_all[1],X_all[2],X_all[3],X_all[4],X_all[5],X_all[6],X_all[7],X_all[8],X_all[9],X_all[10],X_all[11]]) # [24, 64,64,3]x12 
cnt = 0

for i in prediction:
    pre_ans = i.argmax()  # 예측 레이블
    pre_ans_str = ''
    if pre_ans == 0: 
        pre_ans_str = "B7"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    elif pre_ans == 1: 
        pre_ans_str = "B9"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    elif pre_ans == 2: 
        pre_ans_str = "B10"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    elif pre_ans == 3: 
        pre_ans_str = "B13"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    elif pre_ans == 4: 
        pre_ans_str = "B14"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    elif pre_ans == 5: 
        pre_ans_str = "B15"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    elif pre_ans == 6: 
        pre_ans_str = "B16"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    elif pre_ans == 7: 
        pre_ans_str = "B17"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    else: 
        pre_ans_str = "C"
        print("해당 "+filenames[cnt][0].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    cnt += 1
    '''
    if cnt==24
    elif cnt==72
    elif cnt==120
    elif cnt==144
    elif cnt==168
    elif cnt==192
    elif cnt==216
    elif cnt==240
    elif cnt==384
    '''
acc = model.evaluate([X_all[0],X_all[1],X_all[2],X_all[3],X_all[4],X_all[5],X_all[6],X_all[7],X_all[8],X_all[9],X_all[10],X_all[11]], y_all[0])
print('Test accuracy All:', acc[1])
acc = model.evaluate([X_B7[0],X_B7[1],X_B7[2],X_B7[3],X_B7[4],X_B7[5],X_B7[6],X_B7[7],X_B7[8],X_B7[9],X_B7[10],X_B7[11]], y_B7[0])
print('Test accuracy B7:', acc[1])
acc = model.evaluate([X_B9[0],X_B9[1],X_B9[2],X_B9[3],X_B9[4],X_B9[5],X_B9[6],X_B9[7],X_B9[8],X_B9[9],X_B9[10],X_B9[11]], y_B9[0])
print('Test accuracy B9:', acc[1])
acc = model.evaluate([X_B10[0],X_B10[1],X_B10[2],X_B10[3],X_B10[4],X_B10[5],X_B10[6],X_B10[7],X_B10[8],X_B10[9],X_B10[10],X_B10[11]], y_B10[0])
print('Test accuracy B10:', acc[1])
acc = model.evaluate([X_B13[0],X_B13[1],X_B13[2],X_B13[3],X_B13[4],X_B13[5],X_B13[6],X_B13[7],X_B13[8],X_B13[9],X_B13[10],X_B13[11]], y_B13[0])
print('Test accuracy B13:', acc[1])
acc = model.evaluate([X_B14[0],X_B14[1],X_B14[2],X_B14[3],X_B14[4],X_B14[5],X_B14[6],X_B14[7],X_B14[8],X_B14[9],X_B14[10],X_B14[11]], y_B14[0])
print('Test accuracy B14:', acc[1])
acc = model.evaluate([X_B15[0],X_B15[1],X_B15[2],X_B15[3],X_B15[4],X_B15[5],X_B15[6],X_B15[7],X_B15[8],X_B15[9],X_B15[10],X_B15[11]], y_B15[0])
print('Test accuracy B15:', acc[1])
acc = model.evaluate([X_B16[0],X_B16[1],X_B16[2],X_B16[3],X_B16[4],X_B16[5],X_B16[6],X_B16[7],X_B16[8],X_B16[9],X_B16[10],X_B16[11]], y_B16[0])
print('Test accuracy B16:', acc[1])
acc = model.evaluate([X_B17[0],X_B17[1],X_B17[2],X_B17[3],X_B17[4],X_B17[5],X_B17[6],X_B17[7],X_B17[8],X_B17[9],X_B17[10],X_B17[11]], y_B17[0])
print('Test accuracy B17:', acc[1])
acc = model.evaluate([X_C[0],X_C[1],X_C[2],X_C[3],X_C[4],X_C[5],X_C[6],X_C[7],X_C[8],X_C[9],X_C[10],X_C[11]], y_C[0])
print('Test accuracy C:', acc[1])
# Out:
# (384, 64, 64, 3)
# (384, 9)
# 해당 S10E1_a7-6_s1.png이미지는 B9로 추정됩니다.
# 해당 S11E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S12E1_a7-6_s1.png이미지는 B15로 추정됩니다.
# 해당 S13E1_a7-6_s1.png이미지는 C로 추정됩니다.
# 해당 S14E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S15E1_a7-6_s1.png이미지는 B15로 추정됩니다.
# 해당 S16E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S17E1_a7-6_s1.png이미지는 C로 추정됩니다.
# 해당 S18E1_a7-6_s1.png이미지는 B9로 추정됩니다.
# 해당 S19E1_a7-6_s1.png이미지는 B15로 추정됩니다.
# 해당 S1E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S20E1_a7-6_s1.png이미지는 B15로 추정됩니다.
# 해당 S25E1_a7-6_s1.png이미지는 C로 추정됩니다.
# 해당 S2E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S30E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S35E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S3E1_a7-6_s1.png이미지는 B15로 추정됩니다.
# 해당 S40E1_a7-6_s1.png이미지는 B17로 추정됩니다.
# 해당 S4E1_a7-6_s1.png이미지는 C로 추정됩니다.
# 해당 S5E1_a7-6_s1.png이미지는 B7로 추정됩니다.
# 해당 S6E1_a7-6_s1.png이미지는 C로 추정됩니다.
# 해당 S7E1_a7-6_s1.png이미지는 B15로 추정됩니다.
# 해당 S8E1_a7-6_s1.png이미지는 B13로 추정됩니다.
# 해당 S9E1_a7-6_s1.png이미지는 C로 추정됩니다.
# 해당 S10E1_a11-6_s1.png이미지는 B9로 추정됩니다.
# ...
